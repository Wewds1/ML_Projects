# %% [markdown]
# # 04 Modeling
#
# This notebook runs the ablation study, compares experiments, and surfaces the model that is packaged for deployment.

# %%
from pathlib import Path
import sys

import pandas as pd

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

from src.pipeline import save_artifacts, train_project_artifacts
from src.settings import MODELS_DIR

artifacts = train_project_artifacts()
save_artifacts(artifacts, MODELS_DIR)
metadata = artifacts["metadata"]
metadata["best_experiment"]

# %%
experiment_table = pd.DataFrame(metadata["experiments"]).T[["rmse_log", "r2", "mae_usd", "test_size"]]
experiment_table.sort_values("rmse_log")

# %%
segment_rmse = pd.DataFrame(
    {name: values["segment_rmse_log"] for name, values in metadata["experiments"].items()}
).T
segment_rmse

# %%
print("Vectorizer vocabulary:", metadata["vectorizer_vocabulary_size"])
print("SVD explained variance:", round(metadata["svd_explained_variance"], 4))
